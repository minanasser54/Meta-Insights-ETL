# %%
# !git clone https://github.com/minanasser54/Meta-Insights-ETL.git
# %cd Meta-Insights-ETL
# Out:
# Cloning into 'Meta-Insights-ETL'...
# remote: Enumerating objects: 31, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 31 (delta 4), reused 31 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (31/31), 117.03 KiB | 3.00 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# /content/Meta-Insights-ETL

# %%
# !pip install uv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 73.7 MB/s eta 0:00:00
# ...

# %%
# !uv sync
# Out:
# Using CPython 3.13.15 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Resolved 63 packages in 1ms
# Prepared 57 packages in 2.04s
# Installed 57 packages in 238ms
#  + aiohappyeyeballs==2.7.1
#  + aiohttp==3.14.3
#  + aiosignal==1.4.0
#  + annotated-types==0.8.0
#  + asttokens==3.0.2
#  + attrs==26.1.0
#  + capi-param-builder-python==1.3.0
#  + certifi==2026.7.22
#  + charset-normalizer==3.5.1
#  + comm==0.2.3
#  + curlify==3.0.0
#  + debugpy==1.8.21
#  + executing==2.2.1
#  + facebook-business==26.0.1
#  + frozenlist==1.8.0
#  + greenlet==3.5.5
#  + idna==3.19
#  + ipykernel==7.3.0
#  + ipython==9.17.1
#  + ipython-pygments-lexers==1.1.1
#  + jedi==0.20.0
#  + jupyter-client==8.10.0
#  + jupyter-core==5.9.1
#  + matplotlib-inline==0.2.2
#  + multidict==6.8.0
#  + nest-asyncio2==1.7.2
#  + numpy==2.5.3
#  + packaging==26.3
#  + pandas==3.0.5
#  + parso==0.8.7
#  + pexpect==4.9.0
#  + platformdirs==4.11.8
#  + prompt-toolkit==3.0.53
#  + propcache==0.5.2
# ...

# %% [markdown]
# EDIT THE dotenv and main.py

# %%
# 4. Write your .env — regenerate the token first, then use the NEW one here
# %%writefile .env
METAETL_DATABASE_BACKEND=sqlite
METAETL_SQLITE_PATH=metaetl.sqlite3
METAETL_USER_TOKEN=EAAdaC5iztNkBSYtwfhSk6sxZC76nmR0g3TJVKj12OCPb7ZAnDb0yzL27PEDIsITRVlCGugFt1ZCSIxIW6zcGp0QrMNvkbz5mNGG1jKH5psyd2W0OKBJqlqpEEt7HbdIsGpKz8oXe0H6vZCJz2FXzHegolhyDAwi0OoiP2VuNE0quk1i3KF8qZCuzFInFb7pp7sAZDZD
METAETL_PAGE_ACCESS_TOKEN=
METAETL_API_VERSION=v25.0
METAETL_TOKEN_SOURCE=env
METAETL_TOKEN_QUERY=
METAETL_SQL_SERVER=
METAETL_SQL_DATABASE=DataWarehouse
METAETL_SQL_SCHEMA=STG.Marketing
METAETL_SQL_DRIVER=ODBC Driver 18 for SQL Server
METAETL_SQL_USE_WINDOWS_AUTH=true
METAETL_SQL_USERNAME=
METAETL_SQL_PASSWORD=
METAETL_SQL_ENCRYPT=no
METAETL_LOG_DIRECTORY=logs
METAETL_LOG_LEVEL=INFO
METAETL_POST_INSIGHTS_MODE=recent
METAETL_POST_INSIGHTS_LIMIT=10
# Out:
# Writing .env

# %%
# !uv run main.py
# Out:
# 2026-09-10 06:56:52 | INFO | metaetl | Starting staging ETL
# 2026-09-10 06:56:52 | INFO | metaetl | Extracting Business; last_run=None
# 2026-09-10 06:56:53 | INFO | metaetl | Upserted 8 rows into Business
# 2026-09-10 06:56:53 | INFO | metaetl | Dimension Business completed: 8 rows
# 2026-09-10 06:56:53 | INFO | metaetl | Extracting AdAccount; last_run=None
# 2026-09-10 06:56:56 | INFO | metaetl | Upserted 24 rows into AdAccount
# 2026-09-10 06:56:56 | INFO | metaetl | Dimension AdAccount completed: 24 rows
# 2026-09-10 06:56:56 | INFO | metaetl | Extracting Campaign for 24 account(s); last_run=None
# 2026-09-10 06:57:16 | INFO | metaetl | Processed 24/24 ad accounts for Campaign
# 2026-09-10 06:57:25 | INFO | metaetl | Upserted 2494 rows into Campaign
# 2026-09-10 06:57:25 | INFO | metaetl | Dimension Campaign completed: 2494 rows
# 2026-09-10 06:57:25 | INFO | metaetl | Extracting AdSet for 24 account(s); 2494 campaign IDs loaded from DB; last_run=None
# ...
